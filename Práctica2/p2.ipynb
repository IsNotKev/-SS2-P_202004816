# %% [markdown]
# # Práctica 2
# #### Seminario de Sistemas 2
# Kevin Steve Martinez Lemus
#
# ### Datos Solicitados

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('datos.csv')
df

# %% [markdown]
# #### 1. Extracción y Limpieza de Datos
#
# El código carga un conjunto de datos desde un archivo CSV, realiza limpieza de datos en las columnas 'Review' y 'Duration', eliminando texto no numérico y reemplazando valores nulos por 0's, y luego muestra el DataFrame resultante. Por último, se eliminan filas duplicadas. Y se cambia los valores vacios por 'No Disponible'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('datos.csv')

# Reemplazar valores vacíos en 'Rating' por 0
df['Rating'] = df['Rating'].fillna(0)


# Convertir 'Review' y 'Duration' a float y reemplazar valores vacios por 0
df['Review'] = df['Review'].str.replace(' reviews', '').str.replace(',', '').str.extract('(\d+)').astype(float)
df['Review'] = df['Review'].fillna(0)
df['Duration'] = df['Duration'].str.extract('(\d+)').astype(float)
df['Duration'] = df['Duration'].fillna(0)

df.drop_duplicates(inplace=True)

df.fillna("No Disponible", inplace=True)

df
# Out:
#                                            Course Title  Rating  \
# 0                                     Fashion as Design     4.8
# 1                                Modern American Poetry     4.4
# 2                             Pixel Art for Video Games     4.5
# 3       Distribución digital de la música independiente     0.0
# 4     The Blues: Understanding and Performing an Ame...     4.8
# ...                                                 ...     ...
# 8690  Architecting with Google Kubernetes Engine: Pr...     4.9
# 8691  Computational Thinking for K-12 Educators: Nes...     0.0
# 8692           Cómo combinar y analizar datos complejos     0.0
# 8693  Architecting with Google Kubernetes Engine: Wo...     0.0
# 8694                 Visualizing static networks with R     0.0
#
#                    Level  Duration           Schedule  Review  \
# 0         Beginner level      20.0  Flexible schedule  2813.0
# 1         Beginner level      34.0  Flexible schedule   100.0
# ...

# %% [markdown]
# La limpieza de datos desempeña un papel crucial en la mejora de la calidad y la confiabilidad de los análisis de datos y visualizaciones. Al convertir las columnas 'Review' y 'Duration' a formato numérico y reemplazar los valores vacíos por 0, se garantiza la consistencia de los datos, lo que facilita la generación de gráficos más precisos y significativos. Esto no solo mejora la interpretación de los resultados, sino que también ayuda a evitar errores y distorsiones en las visualizaciones, lo que a su vez permite una comunicación más efectiva de los hallazgos a otras personas.

# %% [markdown]
# #### 2. Calcular el promedio de calificaciones para cada curso
#
# Para calcular el promedio de calificaciones para cada curso se agrupa los datos por el título del curso y calcula el promedio de las calificaciones para cada grupo. Finalmente, imprime el promedio de calificaciones por curso.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('datos.csv')


# Reemplazar valores vacíos en 'Rating' por 0
df['Rating'] = df['Rating'].fillna(0)


# Convertir 'Review' y 'Duration' a float y reemplazar valores vacios por 0
df['Review'] = df['Review'].str.replace(' reviews', '').str.replace(',', '').str.extract('(\d+)').astype(float)
df['Review'] = df['Review'].fillna(0)
df['Duration'] = df['Duration'].str.extract('(\d+)').astype(float)
df['Duration'] = df['Duration'].fillna(0)

df.drop_duplicates(inplace=True)
df.fillna("No Disponible", inplace=True)

df_cleaned = df.dropna(subset=['Rating'])
average_rating = df_cleaned.groupby('Course Title')['Rating'].mean()

print("Promedio de calificaciones por curso:")
average_rating
# Out:
# Promedio de calificaciones por curso:
# Course Title
#  Assisting Public Sector Decision Makers With Policy Analysis                                                          4.8
#  Atención prehospitalaria del ictus agudo y selección de pacientes para tratamiento endovascular con la escala RACE    4.9
#  Build a social media presence for your business using Canva                                                           4.7
#  Build social awareness content for Twitter with Canva                                                                 0.0
#  Comercio, Inmigración y Tipos de Cambio en un Mundo Globalizado                                                       4.9
#                                                                                                                       ...
# 현대 로봇공학, 강좌 2: 로봇 기구학                                                                                                  0.0
# ...

# %% [markdown]
# Calcular el promedio de calificaciones para cada curso nos ofrece una visión general de la calidad percibida de los cursos en el conjunto de datos. Los altos promedios sugieren una satisfacción general de los estudiantes, mientras que los promedios más bajos pueden indicar áreas de mejora en la calidad del contenido o la enseñanza. Esta métrica es útil para evaluar y mejorar la oferta de cursos en plataformas de educación en línea.

# %% [markdown]
# #### 3. Calcular los cursos con mayor y menor rating
#
# El código encuentra el curso con el mayor y el menor rating en el conjunto de datos, utilizando el promedio de calificaciones calculado previamente. Luego, imprime el nombre de cada curso junto con su respectivo rating más alto y más bajo.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('datos.csv')

# Reemplazar valores vacíos en 'Rating' por 0
df['Rating'] = df['Rating'].fillna(0)


# Convertir 'Review' y 'Duration' a float y reemplazar valores vacios por 0
df['Review'] = df['Review'].str.replace(' reviews', '').str.replace(',', '').str.extract('(\d+)').astype(float)
df['Review'] = df['Review'].fillna(0)
df['Duration'] = df['Duration'].str.extract('(\d+)').astype(float)
df['Duration'] = df['Duration'].fillna(0)

df.drop_duplicates(inplace=True)
df.fillna("No Disponible", inplace=True)

df_cleaned = df.dropna(subset=['Rating'])
average_rating = df_cleaned.groupby('Course Title')['Rating'].mean()

max_rating_course = average_rating.idxmax()
min_rating_course = average_rating.idxmin()

max_rating = average_rating[max_rating_course]
min_rating = average_rating[min_rating_course]

print("\nCurso con mayor rating:", max_rating_course, "con un rating de", max_rating)
print("Curso con menor rating:", min_rating_course, "con un rating de", min_rating)
# Out:
# Curso con mayor rating:  التنسيق في مايكروسوفت إكسل | Formatting in MS Excel  con un rating de 5.0
# Curso con menor rating:  Build social awareness content for Twitter with Canva con un rating de 0.0

# %% [markdown]
# El curso "التنسيق في مايكروسوفت إكسل | Formatting in MS Excel" recibió la calificación más alta, con un rating perfecto de 5.0, mientras que "Build social awareness content for Twitter with Canva" obtuvo la calificación más baja, con un rating de 0.0. Esto sugiere una alta valoración para el curso de MS Excel, posiblemente debido a su calidad y utilidad, mientras que el curso de Crear contenido de conciencia social para Twitter con Canva puede requerir mejoras para cumplir con las expectativas de los estudiantes.

# %% [markdown]
# #### 4. Calcular el porcentaje de cursos con horario flexible
#
# El código calcula el porcentaje de cursos con horario flexible en relación con el total de cursos en el conjunto de datos y lo imprime con dos decimales.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('datos.csv')

# Reemplazar valores vacíos en 'Rating' por 0
df['Rating'] = df['Rating'].fillna(0)


# Convertir 'Review' y 'Duration' a float y reemplazar valores vacios por 0
df['Review'] = df['Review'].str.replace(' reviews', '').str.replace(',', '').str.extract('(\d+)').astype(float)
df['Review'] = df['Review'].fillna(0)
df['Duration'] = df['Duration'].str.extract('(\d+)').astype(float)
df['Duration'] = df['Duration'].fillna(0)

df.drop_duplicates(inplace=True)
df.fillna("No Disponible", inplace=True)

total_courses = len(df)
flexible_courses = len(df[df['Schedule'] == 'Flexible schedule'])
percentage_flexible_courses = (flexible_courses / total_courses) * 100

print("\nPorcentaje de cursos con horario flexible: {:.2f}%".format(percentage_flexible_courses))
# Out:
# Porcentaje de cursos con horario flexible: 92.63%

# %% [markdown]
# El porcentaje de cursos con horario flexible es del 92.63%. Esto indica que la gran mayoría de los cursos en el conjunto de datos ofrecen horarios flexibles, lo que brinda a los estudiantes una mayor libertad para adaptar su aprendizaje a sus horarios y necesidades individuales. Esta alta proporción de cursos flexibles puede ser un factor atractivo para muchos estudiantes que buscan opciones de educación en línea que se ajusten a sus compromisos personales y profesionales.

# %% [markdown]
# ### Gráficos
# #### 1. Número de cursos en las principales categorías

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('datos.csv')

# Reemplazar valores vacíos en 'Rating' por 0
df['Rating'] = df['Rating'].fillna(0)


# Convertir 'Review' y 'Duration' a float y reemplazar valores vacios por 0
df['Review'] = df['Review'].str.replace(' reviews', '').str.replace(',', '').str.extract('(\d+)').astype(float)
df['Review'] = df['Review'].fillna(0)
df['Duration'] = df['Duration'].str.extract('(\d+)').astype(float)
df['Duration'] = df['Duration'].fillna(0)

df.drop_duplicates(inplace=True)

# 1. Gráfico de barras que muestra el número de cursos en cada nivel de dificultad
level_counts = df['Level'].value_counts()

plt.figure(figsize=(10, 6))
bars = plt.bar(level_counts.index, level_counts.values, color=['#FF5733', '#C70039', '#900C3F'], edgecolor='black')  # Vertical bar plot with color
plt.title('Número de cursos por nivel de dificultad', fontsize=16, fontweight='bold', color='#2C3E50')  # Title color
plt.xlabel('Nivel de dificultad', fontsize=14, color='#2C3E50')  # Label color
plt.ylabel('Número de cursos', fontsize=14, color='#2C3E50')  # Label color
plt.xticks(rotation=45, fontsize=12, color='#2C3E50')  # Tick color and rotation
plt.yticks(fontsize=12, color='#2C3E50')  # Tick color
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add data labels
for index, value in enumerate(level_counts.values):
    plt.text(index, value, str(value), ha='center', fontsize=12, va='bottom')

plt.show()

# %% [markdown]
# El gráfico muestra que la mayoría de los cursos están dirigidos a estudiantes principiantes, seguidos por cursos para estudiantes intermedios y avanzados en menor cantidad. Esto sugiere una amplia disponibilidad de opciones para principiantes, mientras que los estudiantes avanzados pueden encontrar menos cursos adecuados a su nivel.

# %% [markdown]
# #### 2. Número de cursos en las principales categorías

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('datos.csv')

# Reemplazar valores vacíos en 'Rating' por 0
df['Rating'] = df['Rating'].fillna(0)


# Convertir 'Review' y 'Duration' a float y reemplazar valores vacios por 0
df['Review'] = df['Review'].str.replace(' reviews', '').str.replace(',', '').str.extract('(\d+)').astype(float)
df['Review'] = df['Review'].fillna(0)
df['Duration'] = df['Duration'].str.extract('(\d+)').astype(float)
df['Duration'] = df['Duration'].fillna(0)

df.drop_duplicates(inplace=True)

# 2. Gráfico de barras horizontal que muestra el número de cursos en las principales categorías
# Extracting main categories
category_counts = df['Keyword'].value_counts()

# Style customization
plt.figure(figsize=(10, 6))
bars = plt.barh(category_counts.index, category_counts.values, color=['#4CAF50', '#66BB6A', '#81C784', '#A5D6A7', '#C8E6C9'], edgecolor='black')  # Horizontal bar plot with green colors
plt.title('Número de cursos en las principales categorías', fontsize=18, fontweight='bold', color='#424242')  # Title color
plt.xlabel('Número de cursos', fontsize=14, color='#424242')  # Label color
plt.ylabel('Categoría', fontsize=14, color='#424242')  # Label color
plt.xticks(fontsize=12, color='#424242')  # Tick color
plt.yticks(fontsize=12, color='#424242')  # Tick color
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Customizing background
plt.gca().set_facecolor('#E0E0E0')  # Background color
plt.grid(color='white', linewidth=2)  # Grid color

# Add data labels
for index, value in enumerate(category_counts.values):
    plt.text(value, index, str(value), fontsize=12, ha='left', va='center', color='#424242')

plt.show()

# %% [markdown]
# El gráfico de barras horizontal muestra que el número de cursos en las principales categorías es la siguiente: “Social Sciences” tiene el mayor número de cursos, seguida muy de cerca por “Personal Development” y “Health”. Las categorías “Arts and Humanities”, “Math and Logic”, y “Physical Science and Engineering” tienen un número significativamente menor de cursos disponibles. Las áreas relacionadas con la salud, el desarrollo personal y las ciencias sociales son las más representadas en la oferta de cursos.
#
# El gráfico muestra una oferta robusta y variada de cursos, brindando a los estudiantes la oportunidad de encontrar opciones que se adapten a sus intereses y objetivos de aprendizaje.

# %% [markdown]
# #### 3. Gráfico de dispersión

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('datos.csv')

# Reemplazar valores vacíos en 'Rating' por 0
df['Rating'] = df['Rating'].fillna(0)


# Convertir 'Review' y 'Duration' a float y reemplazar valores vacios por 0
df['Review'] = df['Review'].str.replace(' reviews', '').str.replace(',', '').str.extract('(\d+)').astype(float)
df['Review'] = df['Review'].fillna(0)
df['Duration'] = df['Duration'].str.extract('(\d+)').astype(float)
df['Duration'] = df['Duration'].fillna(0)

df.drop_duplicates(inplace=True)

# 3. Gráfico de dispersión para visualizar la relación entre la duración del curso y el número de revisiones
# Style customization
plt.figure(figsize=(10, 6))
plt.scatter(df['Duration'], df['Review'], color='salmon', alpha=0.7, edgecolor='black')  # Scatter plot with salmon color, transparency, and black edges
plt.title('Relación entre duración del curso y número de revisiones', fontsize=18, fontweight='bold', color='#424242')  # Title color
plt.xlabel('Duración del curso (horas)', fontsize=14, color='#424242')  # Label color
plt.ylabel('Número de revisiones', fontsize=14, color='#424242')  # Label color
plt.xticks(fontsize=12, color='#424242')  # Tick color
plt.yticks(fontsize=12, color='#424242')  # Tick color
plt.grid(axis='both', linestyle='--', alpha=0.5)

# Customizing background
plt.gca().set_facecolor('#E0E0E0')  # Background color
plt.grid(color='white', linewidth=2)  # Grid color

plt.show()

# %% [markdown]
# El análisis del gráfico de dispersión revela una relación entre la duración del curso y el número de revisiones. La concentración predominante de puntos entre 0 y 40 horas de duración sugiere que la mayoría de los cursos en el conjunto de datos tienen una duración relativamente corta y reciben un número moderado de revisiones. Esto puede indicar que los estudiantes están más inclinados a revisar y participar en cursos de duración más corta, posiblemente debido a su accesibilidad y capacidad para adaptarse a horarios ocupados. Sin embargo, se necesitaría un análisis más detallado para comprender completamente esta relación y sus implicaciones en el ámbito educativo.

# %% [markdown]
# #### 4. Histograma

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('datos.csv')

# Reemplazar valores vacíos en 'Rating' por 0
df['Rating'] = df['Rating'].fillna(0)


# Convertir 'Review' y 'Duration' a float y reemplazar valores vacios por 0
df['Review'] = df['Review'].str.replace(' reviews', '').str.replace(',', '').str.extract('(\d+)').astype(float)
df['Review'] = df['Review'].fillna(0)
df['Duration'] = df['Duration'].str.extract('(\d+)').astype(float)
df['Duration'] = df['Duration'].fillna(0)

df.drop_duplicates(inplace=True)

# 4. Histograma de la distribución de las duraciones de los cursos
# Estilo personalizado
plt.figure(figsize=(10, 6))
n, bins, patches = plt.hist(df['Duration'], bins=10, color='skyblue', edgecolor='black', linewidth=1.2, alpha=0.7)  # Histograma con color azul cielo, bordes negros y líneas más gruesas
plt.title('Distribución de las duraciones de los cursos', fontsize=18, fontweight='bold', color='#424242')  # Color del título
plt.xlabel('Duración del curso (horas)', fontsize=14, color='#424242')  # Color de la etiqueta x
plt.ylabel('Frecuencia', fontsize=14, color='#424242')  # Color de la etiqueta y
plt.xticks(fontsize=12, color='#424242')  # Color de las marcas del eje x
plt.yticks(fontsize=12, color='#424242')  # Color de las marcas del eje y

# Fondo personalizado
plt.gca().set_facecolor('#E0E0E0')  # Color de fondo

# Agregar cantidades
for rect in patches:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %% [markdown]
# La mayoría de los cursos tienen una duración de 0 a 20 horas, con una disminución significativa en la frecuencia a medida que aumenta la duración del curso. Este histograma muestra la distribución de las duraciones de los cursos, con la barra más alta indicando que hay 5267 cursos con una duración de entre 0 y 20 horas. A medida que aumenta la duración del curso, las barras disminuyen drásticamente en altura, lo que sugiere una menor cantidad de cursos disponibles con largas horas de duración

# %% [markdown]
# #### Gráfico de cajas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('datos.csv')

# Reemplazar valores vacíos en 'Rating' por 0
df['Rating'] = df['Rating'].fillna(0)


# Convertir 'Review' y 'Duration' a float y reemplazar valores vacios por 0
df['Review'] = df['Review'].str.replace(' reviews', '').str.replace(',', '').str.extract('(\d+)').astype(float)
df['Review'] = df['Review'].fillna(0)
df['Duration'] = df['Duration'].str.extract('(\d+)').astype(float)
df['Duration'] = df['Duration'].fillna(0)

df.drop_duplicates(inplace=True)

# 5. Gráfico de cajas para visualizar la distribución de las calificaciones de los cursos por nivel de dificultad
# Estilo personalizado
plt.figure(figsize=(10, 6))
colors = ['#FF5733', '#C70039']  # Colores para cada nivel de dificultad
boxprops = dict(color='black', linewidth=1.5)  # Propiedades de las cajas
medianprops = dict(color='black', linewidth=2)  # Propiedades de la línea de la mediana

df.boxplot(column='Rating', by='Level', grid=False, ax=plt.gca(), boxprops=boxprops, medianprops=medianprops, patch_artist=True, notch=True, flierprops=dict(marker='o', markerfacecolor='red', markersize=8))  # Gráfico de cajas
plt.title('Distribución de las calificaciones por nivel de dificultad', fontsize=18, fontweight='bold', color='#424242')  # Título
plt.suptitle('')  # Eliminar título predeterminado
plt.xlabel('Nivel de dificultad', fontsize=14, color='#424242')  # Etiqueta del eje x
plt.ylabel('Calificación', fontsize=14, color='#424242')  # Etiqueta del eje y
plt.xticks(fontsize=12, color='#424242')  # Tamaño y color de las marcas del eje x
plt.yticks(fontsize=12, color='#424242')  # Tamaño y color de las marcas del eje y

# Aplicar colores personalizados a las cajas
for patch, color in zip(plt.gca().artists, colors):
    patch.set_facecolor(color)

# Fondo personalizado
plt.gca().set_facecolor('#E0E0E0')  # Color de fondo

plt.show()

# %% [markdown]
# La conclusión basada en el gráfico de cajas para visualizar la distribución de las calificaciones de los cursos por nivel de dificultad es la siguiente: los cursos de nivel intermedio y avanzado tienen una distribución similar en sus calificaciones, con una mediana alrededor del valor 4. Los cursos para principiantes muestran una mayor variabilidad en sus calificaciones, con muchos valores atípicos bajos. En general, los cursos parecen tener calificaciones positivas, independientemente del nivel de dificultad.

# %% [markdown]
# ## Conclusiones
#
# #### General
#
# El análisis reveló una amplia variedad de cursos en la plataforma, con una predominancia de opciones para principiantes. Los cursos están bien valorados en general, con algunas excepciones. Además, se observó una fuerte preferencia por cursos con horarios flexibles. Estos hallazgos ofrecen información valiosa para estudiantes y administradores, destacando áreas populares de estudio y la importancia de la flexibilidad en la oferta de cursos.
#
# #### Python
# Python demostró ser una herramienta eficaz en el análisis de datos debido a su facilidad de uso, amplia variedad de bibliotecas especializadas y una comunidad activa de usuarios y desarrolladores. En general, Python se ha consolidado como una herramienta esencial en el análisis de datos y otras aplicaciones, como la inteligencia artificial y el desarrollo web.
